# %%
import pandas as pd
import os

import numpy as np

# %%
file1="Winter.csv"
file2="NewComboJunJulAug.csv"
a=[file1, file2]

# %%
#frames=[]

dataWinter=pd.DataFrame(pd.read_csv('Winter.csv'))
dataSummer=pd.DataFrame(pd.read_csv('NewComboJunJulAug.csv'))

# %%
dataWinter.head()
# Out:
#   Trip Duration     Start Time      Stop Time Start Station ID  \
# 0           148  1/1/2017 0:21  1/1/2017 0:24             3276
# 1          1283  1/1/2017 0:24  1/1/2017 0:45             3183
# 2           372  1/1/2017 0:38  1/1/2017 0:44             3183
# 3          1513  1/1/2017 0:38  1/1/2017 1:03             3194
# 4           639  1/1/2017 1:47  1/1/2017 1:58             3183
#
#   Start Station Name Start Station Latitude Start Station Longitude  \
# 0   Marin Light Rail            40.71458404            -74.04281706
# 1     Exchange Place             40.7162469             -74.0334588
# 2     Exchange Place             40.7162469             -74.0334588
# 3    McGinley Square            40.72533993            -74.06762213
# 4     Exchange Place             40.7162469             -74.0334588
#
#   End Station ID     End Station Name End Station Latitude  \
# 0           3185            City Hall           40.7177325
# ...

# %%
dataWinter.tail()
# Out:
#       Trip Duration       Start Time        Stop Time Start Station ID  \
# 39150           239  3/31/2017 21:26  3/31/2017 21:30             3195
# 39151           192  3/31/2017 21:46  3/31/2017 21:50             3183
# 39152           186  3/31/2017 22:03  3/31/2017 22:07             3183
# 39153           618  3/31/2017 23:20  3/31/2017 23:30             3272
# 39154           649  3/31/2017 23:25  3/31/2017 23:36             3185
#
#       Start Station Name Start Station Latitude Start Station Longitude  \
# 39150            Sip Ave            40.73074263            -74.06378388
# 39151     Exchange Place             40.7162469             -74.0334588
# 39152     Exchange Place             40.7162469             -74.0334588
# 39153       Jersey & 3rd            40.72333159            -74.04595256
# 39154          City Hall             40.7177325              -74.043845
#
#       End Station ID      End Station Name End Station Latitude  \
# ...

# %%
dataSummer.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0           499  6/1/2017 0:01  6/1/2017 0:09              3195
# 1           507  6/1/2017 0:06  6/1/2017 0:15              3211
# 2           768  6/1/2017 0:44  6/1/2017 0:57              3195
# 3           101  6/1/2017 1:12  6/1/2017 1:14              3185
# 4           265  6/1/2017 1:14  6/1/2017 1:18              3273
#
#   start station name  start station latitude  start station longitude  \
# 0            Sip Ave               40.730743               -74.063784
# 1         Newark Ave               40.721525               -74.046305
# 2            Sip Ave               40.730743               -74.063784
# 3          City Hall               40.717733               -74.043845
# 4       Manila & 1st               40.721651               -74.042884
#
#    end station id         end station name  end station latitude  \
# 0            3194          McGinley Square             40.725340
# ...

# %%
dataSummer.tail()
# Out:
#         tripduration        starttime         stoptime  start station id  \
# 101100           416  8/31/2017 23:40  8/31/2017 23:47              3203
# 101101           165  8/31/2017 23:42  8/31/2017 23:45              3186
# 101102           326  8/31/2017 23:42  8/31/2017 23:48              3199
# 101103           345  8/31/2017 23:42  8/31/2017 23:48              3209
# 101104           332  8/31/2017 23:42  8/31/2017 23:48              3209
#
#        start station name  start station latitude  start station longitude  \
# 101100      Hamilton Park               40.727596               -74.044247
# 101101      Grove St PATH               40.719586               -74.043117
# 101102       Newport Pkwy               40.728745               -74.032108
# 101103       Brunswick St               40.724176               -74.050656
# 101104       Brunswick St               40.724176               -74.050656
#
#         end station id end station name  end station latitude  \
# ...

# %%
#frames=[dataSummer, dataWinter]
#result = pd.concat([dataSummer, dataWinter], ignore_index=True)
#result = df1.append(df2), sort=True
#result = dataWinter.append(dataSummer), ignore_index=True

# %%
frames=[file1, file2]
for y in range(0, (len(a))):
    print("processing file:  " + str(y+1))
    dataline=pd.DataFrame(pd.read_csv(a[y]))
    frames.append("data_"+str(y))
    frames[y]=dataline

# %%
result=dataWinter.append(dataSummer, sort=True)
result.to_csv('citibikeLAST.csv', sep=',')
